# %% [markdown]
# <a href="https://colab.research.google.com/github/TimothyAndrewChowles/Coursework/blob/main/Business-Analytics-for-Artificial-Intelligence/Tornado_PandasPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Load the tornado dataset
tornado = pd.read_csv('/content/drive/MyDrive/Fall 2025/Colab Notebooks/tornados.csv')
tornado.head()
# Out:
#     om    yr  mo  dy        date      time               tz  \
# 0  192  1950  10   1  1950-10-01  21:00:00  America/Chicago
# 1  193  1950  10   9  1950-10-09  02:15:00  America/Chicago
# 2  195  1950  11  20  1950-11-20  02:20:00  America/Chicago
# 3  196  1950  11  20  1950-11-20  04:00:00  America/Chicago
# 4  197  1950  11  20  1950-11-20  07:30:00  America/Chicago
#
#            datetime_utc  st  stf  ...   elon   len  wid  ns  sn   f1  f2  f3  \
# 0  1950-10-02T03:00:00Z  OK   40  ... -102.3  15.8   10   1   1   25   0   0
# 1  1950-10-09T08:15:00Z  NC   37  ...    0.0   2.0  880   1   1   47   0   0
# 2  1950-11-20T08:20:00Z  KY   21  ...    0.0   0.1   10   1   1  177   0   0
# 3  1950-11-20T10:00:00Z  KY   21  ...    0.0   0.1   10   1   1  209   0   0
# 4  1950-11-20T13:30:00Z  MS   28  ...    0.0   2.0   37   1   1  101   0   0
#
#    f4     fc
# 0   0  False
# 1   0  False
# 2   0  False
# 3   0  False
# 4   0  False
#
# [5 rows x 27 columns]
# ...

# %%
# Display the shape of the dataframe (number of rows and columns)
tornado.shape
# Out:
# (68693, 27)

# %%
# Display the data for the 5th row (index 4)
tornado.iloc[4]
# Out:
# om                               197
# yr                              1950
# mo                                11
# dy                                20
# date                      1950-11-20
# time                        07:30:00
# tz                   America/Chicago
# datetime_utc    1950-11-20T13:30:00Z
# st                                MS
# stf                               28
# mag                              1.0
# inj                                3
# fat                                0
# loss                         50000.0
# slat                           32.42
# slon                          -89.13
# elat                             0.0
# elon                             0.0
# len                              2.0
# wid                               37
# ns                                 1
# sn                                 1
# f1                               101
# f2                                 0
# f3                                 0
# ...

# %%
# Count the occurrences of each tornado magnitude in Illinois
tornado[tornado.st=="IL"].mag.value_counts() #Illinois
# Out:
# mag
# 0.0    1227
# 1.0     888
# 2.0     403
# 3.0     106
# 4.0      29
# 5.0       2
# Name: count, dtype: int64

# %%
# Count the occurrences of each tornado magnitude in Florida
tornado[tornado.st=="FL"].mag.value_counts() #Florida
# Out:
# mag
# 0.0    2160
# 1.0    1018
# 2.0     333
# 3.0      41
# 4.0       2
# Name: count, dtype: int64

# %%
# Count the occurrences of each tornado magnitude in Oklahoma
tornado[tornado.st=="OK"].mag.value_counts() #Oklahoma
# Out:
# mag
# 0.0    1695
# 1.0    1374
# 2.0     706
# 3.0     195
# 4.0      51
# 5.0       8
# Name: count, dtype: int64

# %%
# Count the occurrences of the strongest tornadoes (magnitude 5) by state
tornado[tornado.mag==5].st.value_counts()
# Out:
# st
# OK    8
# AL    7
# TX    6
# KS    6
# IA    6
# MS    4
# OH    3
# WI    3
# ND    2
# IL    2
# MI    2
# IN    2
# MN    2
# SD    1
# NE    1
# LA    1
# KY    1
# TN    1
# MO    1
# Name: count, dtype: int64

# %%
# Find the state with the most injuries from a single tornado
tornado.iloc[tornado.inj.argmax()].st
# Out:
# 'TX'

# %%
# Find the state with the most fatalities from a single tornado
tornado.iloc[tornado.fat.argmax()].st
# Out:
# 'MO'

# %%
# Find the state with the highest property loss from a single tornado
tornado.iloc[tornado.loss.argmax()].st
# Out:
# 'MO'

# %%
# Count the states that appear in the top 5 tornadoes with the most injuries
tornado.iloc[tornado.inj.nlargest(5).index].st.value_counts()
# Out:
# st
# TX    1
# AL    1
# MA    1
# OH    1
# MO    1
# Name: count, dtype: int64

# %%
# Find the deadliest tornado in Illinois
tornado[tornado.st=="IL"].iloc[tornado[tornado.st=="IL"].inj.argmax()]
# Out:
# om                               186
# yr                              1967
# mo                                 4
# dy                                21
# date                      1967-04-21
# time                        17:24:00
# tz                   America/Chicago
# datetime_utc    1967-04-21T23:24:00Z
# st                                IL
# stf                               17
# mag                              4.0
# inj                              500
# fat                               33
# loss                      50000000.0
# slat                           41.67
# slon                          -87.83
# elat                           41.73
# elon                          -87.55
# len                             15.0
# wid                              200
# ns                                 1
# sn                                 1
# f1                                31
# f2                                 0
# f3                                 0
# ...

# %%
tornado2004 = tornado[tornado.yr >=2004]

# %%
deaths2004 = tornado2004.iloc[tornado.inj.argmax()]
print(deaths2004)
# Out:
# om                            617943
# yr                              2019
# mo                                 5
# dy                                29
# date                      2019-05-29
# time                        16:08:00
# tz                   America/Chicago
# datetime_utc    2019-05-29T21:08:00Z
# st                                TX
# stf                               48
# mag                              1.0
# inj                                0
# fat                                0
# loss                        250000.0
# slat                         32.5447
# slon                        -95.8844
# elat                         32.5627
# elon                        -95.8508
# len                             2.33
# wid                              140
# ns                                 1
# sn                                 1
# f1                               467
# f2                                 0
# f3                                 0
# ...
